# %%
import pandas as pd
import numpy as np
import os
import csv
# By Virginia Wang 

"""
TO CREATE A NEW MASTER VCF

This file will take in the old master vcf and a folder containing new files to add and append the new information to a NEW FILE
given additional information about the background, condition, instructor, and year. The intent is that the user will rerun this
file per "batch" of background, condition, instructor, and year files. Refer to the comments for additional instructions or 
follow the ones below:

1) Adjust path to the folder containing the raw vcf files that you would like to append
2) Check that the old master vcf and gene info is named correctly (takes from working directory and adds the filename as seen below)
3) Adjust path to output location as well as output file name 
4) Adjust background, condition, instructor, and year names 
5) Run all cells
6) Check output to make sure everything was appended correctly 
7) REPLACE OLD MASTER VCF and change filename accordingly 

*NOTE: sample name will be taken from filename (anything before "_S" appears in filename) ex: D15_S17_samtools_filtered.vcf -> sample = D15
if sample is not found, it will print "sample?" in its place
*NOTE: This program assumes the following information
    a) the .txt raw vcf files will have 47 lines of (unnecessary) header information 
    b) the .txt raw vcf files have the same format as given samples (CHROM POS ID ...)
    c) the gene can be found in the gene_info vcf given the region 
"""
#####################################################################
## %% TO DO: YOU SHOULD CHANGE THIS SECTION AND THIS SECTION ONLY   #
## TO DO: Replace with path to folder with your data.               #
path_FOLDER = r"/Users/virginiawang/Desktop/VCFs"    #
                                                                    #
## TO DO: Change output path as necessary. Example shown below.     #
path_OUTPUT = r"/Users/virginiawang/Desktop/VCFs"         #
output_name = "new_master_vcf.csv"                                      #
                                                                    #
## TO DO: type in necessary information below                       #
background = "" #if empty, it will default to S288c                 #
condition = ""                                                      #
instructor = ""                                                     #
year = ""                                                           #
# sample = (based on file name later below)                         #
                                                                    #
# path to master vcf to add to (change filename/path if needed)     #
path_MASTER = os.path.join(os.getcwd(), "all_yEvo_vcf.csv")         #
                                                                    #
# path to gene info csv to match with region                        #
path_GENEINFO = os.path.join(os.getcwd(),"gene_info.csv")           #
                                                                    #
#####################################################################

# %%
# Grabbing master vcf (to change) and gene_info (for matching)
master_yEvo = pd.read_csv(path_MASTER)
gene_info = pd.read_csv(path_GENEINFO)

# Iterate through vcf files in the folder
for filename in os.listdir(path_FOLDER):
    # Construct the full file path
    if "vcf" in filename:
        file_path = os.path.join(path_FOLDER, filename)
        print(file_path)
        # Open individual files
        with open(file_path, 'r') as txt_file:
            # Skip to the 48th line to grab necessary data
            for i, line in enumerate(txt_file):
                if i >= 48:
                # next(txt_file)
            # Read the 48th line and strip any leading/trailing whitespaces, split into array by tabs
                    data = line.strip().split('\t')
                    # print(data)
                    # Grab region
                    region = data[11]

                    # Search to find corresponding gene in gene_info
                    if region == "NA":
                        gene = "NA"
                    else:
                        matching_rows = gene_info[gene_info.iloc[:, 0].str.contains(region, case=False, na=False)]
                        if matching_rows.empty:
                            gene = 'NA'
                        else:
                            gene = matching_rows.iloc[:, 1].values[0]

                    # Extract everything before "_S" for sample name
                    sample = filename[:filename.find('_S')] if filename.find('_S') != -1 else "sample?"

                    CHROM = data[0]
                    POS = data[1]
                    ID = data[2]
                    REF = data[3]
                    ALT = data[4]
                    QUAL = data[5]
                    FILTER = data[6]
                    INFO = data[7]
                    ANNOTATION = data[10]
                    REGION = region
                    GENE = gene
                    PROTEIN = data[12]
                    seq_file = filename
                    if background == "":
                        background = "S288c"

                    # add to dataframe
                    columns = [CHROM, POS, ID, REF, ALT, QUAL, FILTER, INFO, ANNOTATION, REGION, GENE, PROTEIN, seq_file, background, condition, instructor, year, sample]
                    master_yEvo.loc[len(master_yEvo)] = columns

# save dataframe as csv w/ output name in output path 
master_yEvo.to_csv(os.path.join(path_OUTPUT, output_name), index=False)
master_yEvo.tail()
# Out:
# /Users/virginiawang/Desktop/VCFs/Q20_S13_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/V20_S18_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/J20_S6_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/AF16reseq_S39_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/Z20_S22_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/AE16reseq_S38_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/P20_S12_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/W20_S19_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/AD16reseq_S37_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/U20_S17_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/R20_S14_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/O20_S11_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/T20_S16_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/M20_S9_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/N20_S10_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/S20_S15_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/I20_S5_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/AH16reseq_S41_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/AA16reseq_S35_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/AB0reseq_S34_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/K20_S7_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/Y20_S21_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/L20_S8_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/AB16reseq_S36_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/X20_S20_samtools_filtered.vcf.txt
# /Users/virginiawang/Desktop/VCFs/AG16reseq_S40_samtools_filtered.vcf.txt
#        CHROM     POS ID         REF      ALT QUAL FILTER  \
# 1136    chrM    4297  .           A        C   84   PASS
# 1137  chrXIV  204073  .           T        C  228   PASS
# 1138  chrXIV  203581  .           C        T  222   PASS
# 1139    chrM   56281  .           T        G  125   PASS
# 1140  chrXII  867586  .  GTATTATTAT  GTATTAT  222   PASS
#
#                                                    INFO            ANNOTATION  \
# 1136  DP=160;VDB=0.000754272;SGB=-0.693147;RPB=0.861...  coding-nonsynonymous
# 1137  DP=222;VDB=0.970614;SGB=-0.693147;RPB=0.990023...  coding-nonsynonymous
# 1138  DP=191;VDB=0.0790263;SGB=-0.693147;RPB=0.51871...  coding-nonsynonymous
# 1139  DP=182;VDB=0.146278;SGB=-0.693147;RPB=0.001589...            intergenic
# 1140  INDEL;IDV=32;IMF=0.5;DP=64;VDB=0.086345;SGB=-0...  coding-nonsynonymous
#
#        REGION   GENE   PROTEIN                                 seq_file  \
# 1136    Q0017  Q0017      H15P         K20_S7_samtools_filtered.vcf.txt
# 1137  YNL238W   KEX2     F549S         K20_S7_samtools_filtered.vcf.txt
# 1138  YNL238W   KEX2     S385F  AB16reseq_S36_samtools_filtered.vcf.txt
# 1139       NA     NA        NA        X20_S20_samtools_filtered.vcf.txt
# 1140  YLR372W   ELO3  S78indel        X20_S20_samtools_filtered.vcf.txt
#
#      background condition instructor year     sample
# 1136      S288c                                  K20
# 1137      S288c                                  K20
# 1138      S288c                            AB16reseq
# 1139      S288c                                  X20
# 1140      S288c                                  X20
